# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/real estate.csv')

# %%
df.head()
# Out:
#    property_id                            address neighbourhood  \
# 0     10000000  18230 107A STREET NW Edmonton, AB      CHAMBERY
# 1     10000001  18234 107A STREET NW Edmonton, AB      CHAMBERY
# 2     10000002  18238 107A STREET NW Edmonton, AB      CHAMBERY
# 3     10000003  18242 107A STREET NW Edmonton, AB      CHAMBERY
# 4     10000004   18203 107 STREET NW Edmonton, AB      CHAMBERY
#
#                   ward  assessed_value garage   latitude   longitude  \
# 0  tastawiyiniwak Ward          428500      Y  53.644496 -113.510582
# 1  tastawiyiniwak Ward          438500      Y  53.644589 -113.510570
# 2  tastawiyiniwak Ward          439000      Y  53.644682 -113.510559
# 3  tastawiyiniwak Ward          440000      Y  53.644785 -113.510550
# 4  tastawiyiniwak Ward          487500      Y  53.644628 -113.508435
#
#    lot_size_sf  total_living_area_sf  ...  improvement_value  bedrooms  \
# 0      395.758                 137.0  ...             278525         4
# 1      364.863                 136.9  ...             285025         4
# 2      364.866                 151.4  ...             285350         4
# 3      424.504                 136.8  ...             286000         4
# 4      551.298                 133.3  ...             316875         4
#
#    bathrooms            basement       property_type         property_use  \
# 0        2.0            Finished              Duplex      Rental Property
# 1        2.0                 NaN  Single Family Home          Residential
# 2        2.0            Finished         Row Housing  Investment Property
# 3        2.0          Unfinished  Single Family Home          Residential
# 4        2.5  Partially Finished  Single Family Home      Rental Property
#
#   building_age price_per_sqft  land_to_building_ratio  annual_tax
# 0           22    3127.737226                2.888745        5142
# 1           22    3203.067933                2.665179        5262
# 2           22    2899.603699                2.409947        5268
# 3           22    3216.374269                3.103099        5280
# 4           22    3657.164291                4.135769        5850
#
# [5 rows x 22 columns]

# %%
df.describe()
# Out:
#         property_id  assessed_value      latitude     longitude   lot_size_sf  \
# count  1.417700e+04    1.417700e+04  14177.000000  14177.000000  14177.000000
# mean   1.000651e+07    3.476147e+05     53.518012   -113.510726    985.340281
# std    1.311033e+05    2.200800e+05      0.071798      0.077405   1442.805557
# min    1.001601e+06    4.000000e+03     53.415317   -113.696792      0.144000
# 25%    1.000412e+07    1.770000e+05     53.455027   -113.549023    258.200000
# 50%    1.000845e+07    3.845000e+05     53.519781   -113.511140    395.868000
# 75%    1.001260e+07    4.890000e+05     53.584526   -113.464687    592.698000
# max    1.001696e+07    1.085000e+06     53.645303   -113.333474   9000.000000
#
#        total_living_area_sf    year_built     land_value  improvement_value  \
# count          14177.000000  14177.000000   14177.000000       14177.000000
# mean             129.259722   1997.830782  121665.154828      225949.573252
# std               94.675069     14.345210   77027.999199      143051.998512
# min               13.600000   1916.000000    1400.000000        2600.000000
# 25%               90.000000   2002.000000   61950.000000      115050.000000
# 50%              118.900000   2003.000000  134575.000000      249925.000000
# 75%              163.500000   2004.000000  171150.000000      317850.000000
# max             2700.000000   2024.000000  379750.000000      705250.000000
#
#            bedrooms     bathrooms  building_age  price_per_sqft  \
# count  14177.000000  14177.000000  14177.000000    14177.000000
# mean       3.245821      1.846865     27.169218     2582.420768
# std        1.007111      0.723650     14.345210     2001.851384
# min        2.000000      1.000000      1.000000       39.823009
# 25%        2.000000      1.000000     21.000000     1905.555556
# 50%        3.000000      2.000000     22.000000     2828.009828
# 75%        4.000000      2.500000     23.000000     3208.676141
# max        5.000000      3.500000    109.000000    29464.285710
#
#        land_to_building_ratio    annual_tax
# count            14177.000000  14177.000000
# mean                17.950484   4171.376737
# std                 38.838057   2640.959973
# min                  0.000269     48.000000
# 25%                  2.063693   2124.000000
# 50%                  2.579878   4614.000000
# 75%                  3.738427   5868.000000
# max                233.500000  13020.000000

# %%
df.isnull().sum()
# Out:
# property_id                  0
# address                      0
# neighbourhood                0
# ward                         0
# assessed_value               0
# garage                       0
# latitude                     0
# longitude                    0
# lot_size_sf                  0
# total_living_area_sf         0
# year_built                   0
# land_value                   0
# improvement_value            0
# bedrooms                     0
# bathrooms                    0
# basement                  2128
# property_type                0
# property_use                 0
# building_age                 0
# price_per_sqft               0
# land_to_building_ratio       0
# annual_tax                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)
